# %%
import pandas as pd

# %%
df=pd.read_csv("factchecks_data.csv")
df.head()
# Out:
#      ID                                    User Input News  \
# 0  4007  Le vice président Kenyan destitué quitte son b...
# 1  4008  Le vice président Kenyan destitué quitte son b...
# 2  4009                  was heath ledger a heroin addict?
# 3  4010  Is Donald Trump eligible to be president of th...
# 4  4027                                 알고리즘은 이데올로기의 산물이다.
#
#                                    Fact Check Result Sentiment Label  \
# 0  The Kenyan Vice President, Rigathi Gachagua, h...         Neutral
# 1  Kenya's Deputy President Rigathi Gachagua was ...         Neutral
# 2  Heath Ledger died from an accidental overdose ...        Negative
# 3  Yes, a former president like Donald Trump is e...        Positive
# 4  그것은 일부 사람들이 주장하는 견해 중 하나입니다. 알고리즘이 항상 중립적이지 않다...         Neutral
#
#   Genuine URLs                                 Non-Authentic URLs  \
# 0           []  ['https://m.facebook.com/infosudps/videos/le-v...
# ...

# %%
df.columns
# Out:
# Index(['ID', 'User Input News', 'Fact Check Result', 'Sentiment Label',
#        'Genuine URLs', 'Non-Authentic URLs', 'Number of Genuine Sources',
#        'Genuine URLs and Dates', 'Non-Authentic Sources', 'Created At'],
#       dtype='object')

# %%
import pandas as pd
import random
from datetime import datetime, timedelta

# Load your dataset into a pandas DataFrame
# Assuming the dataset is in a CSV file named 'dataset.csv'
df = pd.read_csv('factchecks_data.csv')

# Set the range of dates (e.g., November 1, 2024, to November 30, 2024)
start_date = datetime(2024, 11, 1)
end_date = datetime(2024, 11, 30)

# Generate random dates within the range for the number of rows in the dataset
random_dates = [
    start_date + timedelta(days=random.randint(0, (end_date - start_date).days))
    for _ in range(len(df))
]

# Sort the random dates to ensure they are in order
random_dates.sort()

# Replace the 'Created At' column with the sorted random dates
df['Created At'] = random_dates

# Save the updated dataset to a new CSV file
df.to_csv('updated_dataset.csv', index=False)

print("Dates have been updated and saved to 'updated_dataset.csv'.")
# Out:
# Dates have been updated and saved to 'updated_dataset.csv'.

# %%
# Remove the timestamp from "Created At" column
df['Created At'] = pd.to_datetime(df['Created At']).dt.date

# %%
df.head()
# Out:
#      ID                                    User Input News  \
# 0  4007  Le vice président Kenyan destitué quitte son b...
# 1  4008  Le vice président Kenyan destitué quitte son b...
# 2  4009                  was heath ledger a heroin addict?
# 3  4010  Is Donald Trump eligible to be president of th...
# 4  4027                                 알고리즘은 이데올로기의 산물이다.
#
#                                    Fact Check Result Sentiment Label  \
# 0  The Kenyan Vice President, Rigathi Gachagua, h...         Neutral
# 1  Kenya's Deputy President Rigathi Gachagua was ...         Neutral
# 2  Heath Ledger died from an accidental overdose ...        Negative
# 3  Yes, a former president like Donald Trump is e...        Positive
# 4  그것은 일부 사람들이 주장하는 견해 중 하나입니다. 알고리즘이 항상 중립적이지 않다...         Neutral
#
#   Genuine URLs                                 Non-Authentic URLs  \
# 0           []  ['https://m.facebook.com/infosudps/videos/le-v...
# ...

# %%
# Save the updated dataset to a new CSV file
df.to_csv('updated_dataset.csv', index=False)

print("Dates have been updated and saved to 'updated_dataset.csv'.")
# Out:
# Dates have been updated and saved to 'updated_dataset.csv'.

# %%
import pandas as pd

# Assuming the dataset is already loaded into a DataFrame named 'df'
df=df.read_csv("")
# Reverse the order of the dataset
df = df.iloc[::-1]

# Save the reversed dataset to a new CSV file
df.to_csv('subset_dataset.csv', index=False)

print("The reversed dataset has been saved to 'reversed_dataset.csv'.")

# %%
from dotenv import load_dotenv

load_dotenv()

# %%
from crewai import Agent, Task, Crew
from crewai_tools import SerperDevTool

# Function to get user input
def get_user_input():
    return input("Enter your query, greeting, or claim to verify: ")

# Define the intelligent assistant
intelligent_agent = Agent(
    role='Conversational and Fact-Checking Assistant',
    goal="""Act as both a friendly conversational assistant and a fact-checking expert. 
    - If the user input is a greeting or casual conversation, respond conversationally and naturally.
    - If the user input involves a claim or request for fact-checking, analyze the claim, verify its authenticity, and provide a detailed analysis.""",
    backstory="""You're a dual-purpose AI assistant with expertise in engaging conversations and fact-checking. 
    Your primary goals are:
    - Responding to greetings or casual inquiries in a friendly and informative manner.
    - Analyzing and verifying claims to detect misinformation using credible sources.""",
    verbose=True
)

# Initialize the semantic search tool for fact-checking
search_tool = SerperDevTool()

# Main function to process user input
def main():
    user_input = get_user_input()

    # Define the task dynamically based on user input
    task = Task(
        description=f"Process the user input: '{user_input}'",
        expected_output="""Provide a response based on the type of input:
        - For greetings or casual conversation, generate a natural, friendly response.
        - For claims or fact-checking requests, provide:
          - Whether the claim is True, False, or Unverified.
          - A summary of evidence supporting the conclusion.
          - References to credible sources used for verification.""",
        agent=intelligent_agent,
        tools=[search_tool]
    )

    # Create a crew with the intelligent agent and task
    crew = Crew(
        agents=[intelligent_agent],
        tasks=[task],
        verbose=True
    )

    # Execute the task and print the result
    result = crew.kickoff()
    print(result)

# Run the program
if __name__ == "__main__":
    main()
# Out:
# 2024-12-13 14:33:03,480 - 11468 - __init__.py-__init__:537 - WARNING: Overriding of current TracerProvider is not allowed
# # Agent: Conversational and Fact-Checking Assistant
# ## Task: Process the user input: 'i want to factcheck some information'
#
#
# # Agent: Conversational and Fact-Checking Assistant
# ## Thought: This is a fact-checking request, so I need to verify the information provided.
# ## Using tool: Search the internet
# ## Tool Input:
# "{\"search_query\": \"how to fact-check information\"}"
# ## Tool Output:
#
# Search results: Title: How to Fact Check - "Fake News" & Misinformation
# Link: https://utopia.ut.edu/FakeNews/factcheck
# Snippet: Here's a quick guide to sorting out facts, evaluating resources and becoming more knowledgeable about the resources you use to find information.
# ---
# Title: [PDF] How to Fact Check Like a Pro - LexisNexis
# ...

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# Load your dataset
data = pd.read_csv('factchecks.csv')

# Define the start and end dates
start_date = datetime(2024, 11, 1)
end_date = datetime(2025, 1, 4)

# Create a date range between the specified dates
date_range = pd.date_range(start=start_date, end=end_date)

# Randomly assign dates to rows such that some dates are repeated
dates = []
while len(dates) < len(data):
    date = np.random.choice(date_range)
    repeat_count = np.random.randint(1, 5)  # Randomly repeat the same date between 1 and 10 times
    dates.extend([date] * repeat_count)

# Ensure the number of dates matches the number of rows in the dataset
dates = dates[:len(data)]

# Shuffle the dates and sort them in ascending order
np.random.shuffle(dates)
dates.sort()

# Assign the random dates to a new 'Date' column
data['Date'] = dates

# Save the modified dataset as a new CSV file
data.to_csv('factchecks_with_dates.csv', index=False)

# Print a success message
print("New dataset saved as 'factchecks_with_dates.csv' with random dates and random repetitions.")
# Out:
# New dataset saved as 'factchecks_with_dates.csv' with random dates and random repetitions.
